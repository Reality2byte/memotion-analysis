# %%
import pandas as pd

# %%
fname = 'Twisted-V-twisted-memotion_eq_onlysarcastic.csv'

df = pd.read_csv(fname)
#Gen-V-twisted-memotion_eq_onlysarcastic.csv
#Hil-fun-memotion_eq_onlyfunny.csv
#Twisted-V-twisted-memotion_eq_onlysarcastic.csv
#Hil-V-fun-memotion_eq_onlyfunny.csv

# %%
df.head()
# Out:
#           img_name                                        cleaned_ocr  \
# 0   image_4474.jpg  need feminism www love whining everything nothing
# 1  image_1241.jpeg         bigger balls mine put chest avoid chaffing
# 2   image_4749.png                             funny like deport last
# 3   image_4990.jpg       everyone oscar may leave early today roflbot
# 4   image_4678.jpg     david steele left rest stop didnt go smith qoc
#
#    twisted_meaning  very_twisted
# 0                1             0
# 1                1             0
# 2                1             0
# 3                1             0
# 4                1             0

# %%
#df = df.iloc[:20,:]

# %%
# fun = []
# for i in range(len(df)):
#     if df['very_twisted'][i] ==1 or df['twisted_meaning'][i] == 1 or df['general'][i] == 1:
#         fun.append(1)
#     else:
#         fun.append(0)

# df['sarcastic'] = fun

# %%
columns = ['hilarious','very_funny','funny','general', 'twisted_meaning', 'very_twisted', 'not_sarcastic','not_offensive','not_funny','motivational','not_motivational', 'positive', 'neutral', 'negative']
#'very_offensive', 'slight', 'hateful_offensive',
for i in columns:
    del df[i]

# %%
df
# Out:
#              img_name                                        cleaned_ocr  \
# 0      image_4474.jpg  need feminism www love whining everything nothing
# 1     image_1241.jpeg         bigger balls mine put chest avoid chaffing
# 2      image_4749.png                             funny like deport last
# 3      image_4990.jpg       everyone oscar may leave early today roflbot
# 4      image_4678.jpg     david steele left rest stop didnt go smith qoc
# 5      image_2975.png                     never drinking oh look alcohol
# 6       image_344.png  joshua jlewdatruth follow gets asked ya doin w...
# 7      image_2600.png  short people mcnugget funny minion meme people...
# 8      image_5949.jpg  one friend gets overly affectionate drunk abc ...
# 9      image_3225.jpg   picard sorry hear sound awesome memes funny pics
# 10     image_1885.jpg                                    praying houston
# 11     image_1698.jpg                              yolos live one season
# ...

# %%
is_mot = df['twisted_meaning'] == 1
df_mot = df[is_mot]
len(df_mot)
# Out:
# 1547

# %%
is_mott = df['very_twisted'] == 1
df_mott = df[is_mott]
len(df_mott)
# Out:
# 1576

# %%
df_mott = df_mott.iloc[:1000,:]
#df_mot

# %%
400*8
# Out:
# 3200

# %%
#df_neg

# %%
df = df.append([df_mot]*1,ignore_index=True)

# %%
df = df.append([df_mott]*3,ignore_index=True)

# %%
df
# Out:
#              img_name                                        cleaned_ocr  \
# 0      image_4474.jpg  need feminism www love whining everything nothing
# 1     image_1241.jpeg         bigger balls mine put chest avoid chaffing
# 2      image_4749.png                             funny like deport last
# 3      image_4990.jpg       everyone oscar may leave early today roflbot
# 4      image_4678.jpg     david steele left rest stop didnt go smith qoc
# 5      image_2975.png                     never drinking oh look alcohol
# 6       image_344.png  joshua jlewdatruth follow gets asked ya doin w...
# 7      image_2600.png  short people mcnugget funny minion meme people...
# 8      image_5949.jpg  one friend gets overly affectionate drunk abc ...
# 9      image_3225.jpg   picard sorry hear sound awesome memes funny pics
# 10     image_1885.jpg                                    praying houston
# 11     image_1698.jpg                              yolos live one season
# ...

# %%
df.to_csv(fname,index=False)

# %%
6992+3200
# Out:
# 10192

# %%
#4160

# %%
#2201

# %%
#631*7
# Out:
# 4417

# %%
#2201*2
# Out:
# 4402

# %%
4402+4417+4160
# Out:
# 12979

# %%
4525+1569+2467
# Out:
# 8561

# %%
1651*2
# Out:
# 3302

# %%
4953+5341
# Out:
# 10294

# %%
1651+5431+

# %%
4279+2713
# Out:
# 6992

# %%
2713+1569+4279
# Out:
# 8561

# %%
5448
# Out:
# 5448

# %%
1544*4
# Out:
# 6176

# %%
4000+1500+5400
# Out:
# 10900

# %%
3507
# Out:
# 3507

# %%
1547
# Out:
# 1547

# %%
394*9
# Out:
# 3546

# %%
1547*2
# Out:
# 3094

# %%
394*9
# Out:
# 3546

# %%
3546+3094+3507
# Out:
# 10147
